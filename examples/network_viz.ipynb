# %%
import qbiome.network as qbnet
networkfile='tmp.png'

# %%
network=qbnet.Network('./hypothesis_phylum_31_33_-1.dot',outfile=networkfile)

# %%
network.get()

# %%
from IPython.display import Image
from IPython.core.display import HTML 
Image(filename=networkfile)

# %%
network2=qbnet.Network('./hypothesis_phylum_32_34_-2.dot',outfile='tmp4.png')
network2.get()
Image(filename='tmp4.png')

# %%
network3=qbnet.Network('./hypothesis_phylum_32_34_-2.dot',
                       outfile='tmp5.png',
                       strongcomponent=False)
network3.get()
Image(filename='tmp5.png')
